# %%
from mj_etc import ETC
import matplotlib.pyplot as plt

# %%
etc = ETC('moaR','MOA','1.8m',moon_phase='bright')
etc.time_for_snr(5,mag=22,plot=True)
plt.savefig('test_fig.png')

# %%
import tessreduce as tr
# %matplotlib notebook

# %%
obs = tr.spacetime_lookup('22 41 18.6675548450','-43 50 28.593748832')
tess = tr.tessreduce(obs_list=obs[1],reduce=False,plot=True,size=50)
tess.reduce(diff=False)
# Out:
# !!! WARNING no MJD time specified, using default of 59000
# |   Sector | Covers   |   Time difference  |
# |          |          |             (days) |
# |----------+----------+--------------------|
# |        1 | False    |               -648 |
# |       28 | False    |                 60 |
# getting TPF from TESScut
# Exception ignored in: <function FITS_rec.__del__ at 0x7fd2f02417a0>
# Traceback (most recent call last):
#   File "/Users/rridden/miniconda3/lib/python3.7/site-packages/astropy/io/fits/fitsrec.py", line 636, in __del__
#     col.array = col.array.copy()
# KeyboardInterrupt:
# made reference
# made source mask
# calculating background
# background subtracted
# calculating centroids
# <img src="data:image/png;base64,..." width="374.9999944120646">
# images shifted
# Field calibration
# Target is below -30 dec, calibrating to SkyMapper photometry.
# <img src="data:image/png;base64,..." width="374.9999944120646">
# ...
